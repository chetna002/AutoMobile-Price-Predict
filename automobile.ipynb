# %% [markdown]
# # import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option("display.max_columns",None)

# %%
df=pd.read_csv(r"C:\Users\uzuma\Downloads\EDA_Automobile_Case_Price_pred.csv")

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.select_dtypes(include="O").columns
# Out:
# Index(['normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'engine-type',
#        'num-of-cylinders', 'fuel-system', 'bore', 'stroke', 'horsepower',
#        'peak-rpm', 'price'],
#       dtype='object')

# %%
df.select_dtypes(exclude="O").columns
# Out:
# Index(['symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight',
#        'engine-size', 'compression-ratio', 'city-mpg', 'highway-mpg'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
columns=['symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight',
       'engine-size', 'compression-ratio', 'city-mpg', 'highway-mpg']

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df[columns])
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["normalized-losses"]
# Out:
# 0        ?
# 1        ?
# 2        ?
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object

# %%
df["normalized-losses"]=df["normalized-losses"].replace("?",np.nan)

# %%
df["normalized-losses"].fillna(df["normalized-losses"].mode()[0],inplace=True)
# Out:
# C:\Users\uzuma\AppData\Local\Temp\ipykernel_5224\898238595.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["normalized-losses"].fillna(df["normalized-losses"].mode()[0],inplace=True)

# %%
df["normalized-losses"]=df["normalized-losses"].astype("int")

# %%
df["num-of-doors"].unique()
# Out:
# array(['two', 'four', '?'], dtype=object)

# %%
df["num-of-doors"]=df["num-of-doors"].replace("?",np.nan)

# %%
df["num-of-doors"].fillna(df["num-of-doors"].mode()[0],inplace=True)
# Out:
# C:\Users\uzuma\AppData\Local\Temp\ipykernel_5224\2153822773.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["num-of-doors"].fillna(df["num-of-doors"].mode()[0],inplace=True)

# %%
df["num-of-doors"]=df["num-of-doors"].map({"two":2,"four":4})

# %%
df["num-of-doors"].unique()
# Out:
# array([2, 4])

# %%
df.head(1)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                161  alfa-romero       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0             2  convertible          rwd           front        88.6   168.8
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# 0   64.1    48.8         2548        dohc             four          130
#
#   fuel-system  bore stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0        mpfi  3.47   2.68                9.0        111     5000        21
#
#    highway-mpg  price
# 0           27  13495

# %%
df.drop(["engine-location"],axis=1,inplace=True)

# %%
df["wheel-base"].isnull().sum()
# Out:
# np.int64(0)

# %%
mini=df["wheel-base"].min()
Q1=df["wheel-base"].quantile(0.25)
Q2=df["wheel-base"].quantile(0.50)
Q3=df["wheel-base"].quantile(0.75)
Max=df["wheel-base"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 114.25000000000001
# Lower- 82.64999999999999

# %%
df[df["wheel-base"]>Upper_fence]
# Out:
#     symboling  normalized-losses           make fuel-type aspiration  \
# 70         -1                 93  mercedes-benz    diesel      turbo
# 71         -1                161  mercedes-benz       gas        std
# 73          0                161  mercedes-benz       gas        std
#
#     num-of-doors body-style drive-wheels  wheel-base  length  width  height  \
# 70             4      sedan          rwd       115.6   202.6   71.7    56.3
# 71             4      sedan          rwd       115.6   202.6   71.7    56.5
# 73             4      sedan          rwd       120.9   208.1   71.7    56.7
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 70         3770         ohc             five          183         idi  3.58
# 71         3740        ohcv            eight          234        mpfi  3.46
# 73         3900        ohcv            eight          308        mpfi   3.8
#
# ...

# %%
df["length"].isnull().sum()
# Out:
# np.int64(0)

# %%
mini=df["length"].min()
Q1=df["length"].quantile(0.25)
Q2=df["length"].quantile(0.50)
Q3=df["length"].quantile(0.75)
Max=df["length"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 208.29999999999995
# Lower- 141.10000000000002

# %%
df[df["length"]<Lower_fence]
# Out:
#     symboling  normalized-losses       make fuel-type aspiration  \
# 18          2                121  chevrolet       gas        std
#
#     num-of-doors body-style drive-wheels  wheel-base  length  width  height  \
# 18             2  hatchback          fwd        88.4   141.1   60.3    53.2
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 18         1488           l            three           61        2bbl  2.91
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg price
# 18   3.03                9.5         48     5100        47           53  5151

# %%
df["length"].unique()
# Out:
# array([168.8, 171.2, 176.6, 177.3, 192.7, 178.2, 176.8, 189. , 193.8,
#        197. , 141.1, 155.9, 158.8, 157.3, 174.6, 173.2, 144.6, 150. ,
#        163.4, 157.1, 167.5, 175.4, 169.1, 170.7, 172.6, 199.6, 191.7,
#        159.1, 166.8, 169. , 177.8, 175. , 190.9, 187.5, 202.6, 180.3,
#        208.1, 199.2, 178.4, 173. , 172.4, 165.3, 170.2, 165.6, 162.4,
#        173.4, 181.7, 184.6, 178.5, 186.7, 198.9, 167.3, 168.9, 175.7,
#        181.5, 186.6, 156.9, 157.9, 172. , 173.5, 173.6, 158.7, 169.7,
#        166.3, 168.7, 176.2, 175.6, 183.5, 187.8, 171.7, 159.3, 165.7,
#        180.2, 183.1, 188.8])

# %%
df["width"]
# Out:
# 0      64.1
# 1      64.1
# 2      65.5
# 3      66.2
# 4      66.4
#        ...
# 200    68.9
# 201    68.8
# 202    68.9
# 203    68.9
# 204    68.9
# Name: width, Length: 205, dtype: float64

# %%
mini=df["width"].min()
Q1=df["width"].quantile(0.25)
Q2=df["width"].quantile(0.50)
Q3=df["width"].quantile(0.75)
Max=df["width"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 71.10000000000002
# Lower- 59.89999999999998

# %%
df[df["width"]>Upper_fence]
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 6            1                158           audi       gas        std
# 7            1                161           audi       gas        std
# 8            1                158           audi       gas      turbo
# 70          -1                 93  mercedes-benz    diesel      turbo
# 71          -1                161  mercedes-benz       gas        std
# 73           0                161  mercedes-benz       gas        std
# 74           1                161  mercedes-benz       gas        std
# 129          1                161        porsche       gas        std
#
#      num-of-doors body-style drive-wheels  wheel-base  length  width  height  \
# 6               4      sedan          fwd       105.8   192.7   71.4    55.7
# 7               4      wagon          fwd       105.8   192.7   71.4    55.7
# 8               4      sedan          fwd       105.8   192.7   71.4    55.9
# ...

# %%
df.loc[df["width"]>Upper_fence,"width"]=0

# %%
df[df["width"]>Upper_fence]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []

# %%
mini=df["height"].min()
Q1=df["height"].quantile(0.25)
Q2=df["height"].quantile(0.50)
Q3=df["height"].quantile(0.75)
Max=df["height"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 60.75
# Lower- 46.75

# %%
df[df["height"]>Upper_fence]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []

# %%
mini=df["curb-weight"].min()
Q1=df["curb-weight"].quantile(0.25)
Q2=df["curb-weight"].quantile(0.50)
Q3=df["curb-weight"].quantile(0.75)
Max=df["curb-weight"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 4120.0
# Lower- 960.0

# %%
df[df["curb-weight"]>Upper_fence]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []

# %%
mini=df["engine-size"].min()
Q1=df["engine-size"].quantile(0.25)
Q2=df["engine-size"].quantile(0.50)
Q3=df["engine-size"].quantile(0.75)
Max=df["engine-size"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 207.0
# Lower- 31.0

# %%
df[df["engine-size"]>Upper_fence]
# Out:
#     symboling  normalized-losses           make fuel-type aspiration  \
# 15          0                161            bmw       gas        std
# 16          0                161            bmw       gas        std
# 17          0                161            bmw       gas        std
# 47          0                145         jaguar       gas        std
# 48          0                161         jaguar       gas        std
# 49          0                161         jaguar       gas        std
# 71         -1                161  mercedes-benz       gas        std
# 72          3                142  mercedes-benz       gas        std
# 73          0                161  mercedes-benz       gas        std
# 74          1                161  mercedes-benz       gas        std
#
#     num-of-doors   body-style drive-wheels  wheel-base  length  width  height  \
# 15             4        sedan          rwd       103.5   189.0   66.9    55.7
# ...

# %%
df.loc[df["engine-size"]>Upper_fence,"engine-size"]=0

# %%
df[df["engine-size"]>Upper_fence]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []

# %%
mini=df["compression-ratio"].min()
Q1=df["compression-ratio"].quantile(0.25)
Q2=df["compression-ratio"].quantile(0.50)
Q3=df["compression-ratio"].quantile(0.75)
Max=df["compression-ratio"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 10.600000000000001
# Lower- 7.399999999999999

# %%
df[df["compression-ratio"]<Lower_fence]
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 9            0                161        audi       gas      turbo
# 29           3                145       dodge       gas      turbo
# 82           3                161  mitsubishi       gas      turbo
# 83           3                161  mitsubishi       gas      turbo
# 84           3                161  mitsubishi       gas      turbo
# 117          0                161      peugot       gas      turbo
# 124          3                161    plymouth       gas      turbo
#
#      num-of-doors body-style drive-wheels  wheel-base  length  width  height  \
# 9               2  hatchback          4wd        99.5   178.2   67.9    52.0
# 29              2  hatchback          fwd        95.9   173.2   66.3    50.2
# 82              2  hatchback          fwd        95.9   173.2   66.3    50.2
# 83              2  hatchback          fwd        95.9   173.2   66.3    50.2
# ...

# %%
df.loc[df["compression-ratio"]<Lower_fence,"compression-ratio"]=9

# %%
df[df["compression-ratio"]<Lower_fence]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []

# %%
df[df["compression-ratio"]>Upper_fence]
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 49           0                161         jaguar       gas        std
# 63           0                161          mazda    diesel        std
# 66           0                161          mazda    diesel        std
# 67          -1                 93  mercedes-benz    diesel      turbo
# 68          -1                 93  mercedes-benz    diesel      turbo
# 69           0                 93  mercedes-benz    diesel      turbo
# 70          -1                 93  mercedes-benz    diesel      turbo
# 90           1                128         nissan    diesel        std
# 108          0                161         peugot    diesel      turbo
# 110          0                161         peugot    diesel      turbo
# 112          0                161         peugot    diesel      turbo
# 114          0                161         peugot    diesel      turbo
# ...

# %%
df.loc[df["compression-ratio"]>Upper_fence,"compression-ratio"]=6

# %%
df[df["compression-ratio"]>Upper_fence]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []

# %%
mini=df["city-mpg"].min()
Q1=df["city-mpg"].quantile(0.25)
Q2=df["city-mpg"].quantile(0.50)
Q3=df["city-mpg"].quantile(0.75)
Max=df["city-mpg"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 46.5
# Lower- 2.5

# %%
mini=df["highway-mpg"].min()
Q1=df["highway-mpg"].quantile(0.25)
Q2=df["highway-mpg"].quantile(0.50)
Q3=df["highway-mpg"].quantile(0.75)
Max=df["highway-mpg"].max()
 
IQR=Q3-Q1
Upper_fence=Q3+(1.5*IQR)
Lower_fence=Q1-(1.5*IQR)

# %%
print("Upper-",Upper_fence)
print("Lower-",Lower_fence)
# Out:
# Upper- 47.5
# Lower- 11.5

# %%
df[df["highway-mpg"]>Upper_fence]
# Out:
#     symboling  normalized-losses       make fuel-type aspiration  \
# 18          2                121  chevrolet       gas        std
# 30          2                137      honda       gas        std
# 90          1                128     nissan    diesel        std
#
#     num-of-doors body-style drive-wheels  wheel-base  length  width  height  \
# 18             2  hatchback          fwd        88.4   141.1   60.3    53.2
# 30             2  hatchback          fwd        86.6   144.6   63.9    50.8
# 90             2      sedan          fwd        94.5   165.3   63.8    54.5
#
#     curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# 18         1488           l            three           61        2bbl  2.91
# 30         1713         ohc             four           92        1bbl  2.91
# 90         2017         ohc             four          103         idi  2.99
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg price
# ...

# %%
df.loc[df["highway-mpg"]>Upper_fence,"highway-mpg"]=0

# %%
df[df["highway-mpg"]>Upper_fence]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []

# %%
df["bore"].unique()
# Out:
# array(['3.47', '2.68', '3.19', '3.13', '3.5', '3.31', '3.62', '2.91',
#        '3.03', '2.97', '3.34', '3.6', '2.92', '3.15', '3.43', '3.63',
#        '3.54', '3.08', '?', '3.39', '3.76', '3.58', '3.46', '3.8', '3.78',
#        '3.17', '3.35', '3.59', '2.99', '3.33', '3.7', '3.61', '3.94',
#        '3.74', '2.54', '3.05', '3.27', '3.24', '3.01'], dtype=object)

# %%
df["bore"]=df["bore"].replace("?",np.nan)

# %%
df["bore"].fillna(df["bore"].mode()[0],inplace=True)
# Out:
# C:\Users\uzuma\AppData\Local\Temp\ipykernel_5224\1632824437.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["bore"].fillna(df["bore"].mode()[0],inplace=True)

# %%
df["bore"]=df["bore"].astype("float")

# %%
df["stroke"]=df["stroke"].replace("?",np.nan)

# %%
df["stroke"].fillna(df["stroke"].mode()[0],inplace=True)
# Out:
# C:\Users\uzuma\AppData\Local\Temp\ipykernel_5224\84194994.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["stroke"].fillna(df["stroke"].mode()[0],inplace=True)

# %%
df["stroke"]=df["stroke"].astype('float')

# %%
df["horsepower"]=df["horsepower"].replace("?",np.nan)

# %%
df["horsepower"].fillna(df["horsepower"].mode()[0],inplace=True)
# Out:
# C:\Users\uzuma\AppData\Local\Temp\ipykernel_5224\3850378826.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["horsepower"].fillna(df["horsepower"].mode()[0],inplace=True)

# %%
df["horsepower"]=df["horsepower"].astype('int')

# %%
df["peak-rpm"]
# Out:
# 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500
#        ...
# 200    5400
# 201    5300
# 202    5500
# 203    4800
# 204    5400
# Name: peak-rpm, Length: 205, dtype: object

# %%
df["peak-rpm"]=df["peak-rpm"].replace("?",np.nan)

# %%
df["peak-rpm"].fillna(df["peak-rpm"].mode()[0],inplace=True)
# Out:
# C:\Users\uzuma\AppData\Local\Temp\ipykernel_5224\90037583.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["peak-rpm"].fillna(df["peak-rpm"].mode()[0],inplace=True)

# %%
df["peak-rpm"]=df["peak-rpm"].astype('float')

# %%
df["peak-rpm"].unique()
# Out:
# array([5000., 5500., 5800., 4250., 5400., 5100., 4800., 6000., 4750.,
#        4650., 4200., 4350., 4500., 5200., 4150., 5600., 5900., 5750.,
#        5250., 4900., 4400., 6600., 5300.])

# %%
df["price"]
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: object

# %%
df["price"]=df["price"].replace("?",np.nan)

# %%
df["price"].fillna(df["price"].mode()[0],inplace=True)
# Out:
# C:\Users\uzuma\AppData\Local\Temp\ipykernel_5224\233073596.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["price"].fillna(df["price"].mode()[0],inplace=True)

# %%
df["price"]=df["price"].astype('int')

# %%
df["price"].unique()
# Out:
# array([13495, 16500, 13950, 17450, 15250, 17710, 18920, 23875, 13499,
#        16430, 16925, 20970, 21105, 24565, 30760, 41315, 36880,  5151,
#         6295,  6575,  5572,  6377,  7957,  6229,  6692,  7609,  8558,
#         8921, 12964,  6479,  6855,  5399,  6529,  7129,  7295,  7895,
#         9095,  8845, 10295, 12945, 10345,  6785, 11048, 32250, 35550,
#        36000,  5195,  6095,  6795,  6695,  7395, 10945, 11845, 13645,
#        15645,  8495, 10595, 10245, 10795, 11245, 18280, 18344, 25552,
#        28248, 28176, 31600, 34184, 35056, 40960, 45400, 16503,  5389,
#         6189,  6669,  7689,  9959,  8499, 12629, 14869, 14489,  6989,
#         8189,  9279,  5499,  7099,  6649,  6849,  7349,  7299,  7799,
#         7499,  7999,  8249,  8949,  9549, 14399, 17199, 19699, 18399,
#        11900, 13200, 12440, 13860, 15580, 16900, 16695, 17075, 16630,
#        17950, 18150, 12764, 22018, 32528, 34028, 37028,  9295,  9895,
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), yticklabels=False, cbar=True, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
df.shape
# Out:
# (205, 25)

# %%
df.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                161  alfa-romero       gas        std
# 1          3                161  alfa-romero       gas        std
# 2          1                161  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#    num-of-doors   body-style drive-wheels  wheel-base  length  width  height  \
# 0             2  convertible          rwd        88.6   168.8   64.1    48.8
# 1             2  convertible          rwd        88.6   168.8   64.1    48.8
# 2             2    hatchback          rwd        94.5   171.2   65.5    52.4
# 3             4        sedan          fwd        99.8   176.6   66.2    54.3
# 4             4        sedan          4wd        99.4   176.6   66.4    54.3
#
#    curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# ...

# %% [markdown]
# # Encode our Data

# %%
df["num-of-cylinders"].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
df["num-of-cylinders"]=df["num-of-cylinders"].map({"four":4,"six":6,"three":3,"eight":8,"five":5,"twelve":12,"two":2})

# %%
df["fuel-type"]=df["fuel-type"].map({"gas":0,"diesel":1})

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type              int64
# aspiration            object
# num-of-doors           int64
# body-style            object
# drive-wheels          object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders       int64
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
columns = df.select_dtypes(include=['object']).columns

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal=OrdinalEncoder()

# %%
df[columns]=ordinal.fit_transform(df[columns])

# %%
df
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                161   0.0          0         0.0             2
# 1            3                161   0.0          0         0.0             2
# 2            1                161   0.0          0         0.0             2
# 3            2                164   1.0          0         0.0             4
# 4            2                164   1.0          0         0.0             4
# ..         ...                ...   ...        ...         ...           ...
# 200         -1                 95  21.0          0         0.0             4
# 201         -1                 95  21.0          0         1.0             4
# 202         -1                 95  21.0          0         0.0             4
# 203         -1                 95  21.0          1         1.0             4
# 204         -1                 95  21.0          0         1.0             4
#
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
x=df.drop("price",axis=1)
y=df["price"]

# %% [markdown]
# # Checking is their any linearity

# %%
plt.scatter(df["normalized-losses"],df["price"])
plt.show()

# %%
plt.scatter(df["wheel-base"],df["price"])
plt.show()

# %%
plt.scatter(df["length"],df["price"])
plt.show()

# %%
plt.scatter(df["curb-weight"],df["price"])
plt.show()

# %%
plt.scatter(df["bore"],df["price"])
plt.show()

# %%
plt.scatter(df["horsepower"],df["price"])
plt.show()

# %%
plt.scatter(df["city-mpg"],df["price"])
plt.show()

# %%
plt.scatter(df["highway-mpg"],df["price"])
plt.show()

# %% [markdown]
# # Training our Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn=MinMaxScaler()

# %%
x= mn.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2,shuffle=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.8528735373540123

# %%
lr.score(x_test,y_test)
# Out:
# 0.8376916327074325

# %%
lr.coef_
# Out:
# array([   91.75024657,  2369.72384428, -3253.80611641,  7793.32439004,
#         1194.7963634 ,  1790.06877524, -9227.63389044,  1944.71770464,
#         -671.65162312,  7527.80159423,   325.70062167,  6092.36845322,
#         5992.98358398,  4647.49730986, 18407.40697699, -9583.71396172,
#         1884.81238369,  3579.20928317, -1295.27151941,  6447.24710283,
#        10137.37049665,  2394.03938675, -4055.13829875,  -870.34297041])

# %%
lr.intercept_
# Out:
# np.float64(-1317.7387728793)

# %%
pred=lr.predict(x_test)

# %%
result=pd.DataFrame(pred,columns=["Base_Model"])

# %%
result["Actual_value"]=np.array(y_test)
result
# Out:
#       Base_Model  Actual_value
# 0   32093.882621         30760
# 1   20052.042323         13499
# 2    8912.234730          9549
# 3   16717.605450         11850
# 4   20992.446268         28248
# 5    8005.821155          7799
# 6    9046.725190          7788
# 7    5622.670940          9258
# 8    9585.271773         10198
# 9    7409.875125          7775
# 10  13878.108789         13295
# 11   8311.462611          8238
# 12  13833.486999         18280
# 13   9664.529274          9988
# 14  39829.372544         40960
# 15   6627.368519          6488
# 16   2062.822705          5151
# 17  14223.968907         12629
# 18   7542.642023          8189
# 19  11228.675440          9960
# 20  10245.170572          8495
# 21  20372.487941         13499
# 22  10409.577842          8249
# 23   2410.417688          6479
# 24   6738.024563          6692
# 25  30181.017683         41315
# 26  14128.102816          9639
# 27  14972.585205         13415
# 28   5511.195295          7999
# ...

# %%
result["Error"]= result["Base_Model"]-result["Actual_value"]

# %%
sns.distplot(result["Error"],bins=50)
plt.show()
# Out:
# C:\Users\uzuma\AppData\Local\Temp\ipykernel_5224\1936403199.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(result["Error"],bins=50)

# %%
from sklearn.linear_model  import Ridge

# %%
ridge=Ridge(alpha=0.5)

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.5)

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.5)

# %%
ridge_pred=ridge.predict(x_test)

# %%
ridge_pred
# Out:
# array([30363.77070989, 18190.79043645,  9309.75853917, 15766.6147534 ,
#        20815.53562891,  7429.61337922,  9060.75333899,  6112.26566461,
#        10035.69199568,  7485.55954034, 13575.01766286,  8689.50960646,
#        15417.44805712, 10094.89233575, 38683.61919276,  6895.94021011,
#         3181.66302957, 14176.58519577,  8591.17882175, 11261.61331207,
#        10385.20783352, 19520.07647496,  9531.07386727,  3383.67023876,
#         6876.85686373, 28834.74399142, 14318.47717675, 15051.46852904,
#         5562.72050975, 16151.21729001, 21178.14985924,  7347.25580136,
#         5484.27105084, 19924.56845088,  9050.23581262, 22478.47800167,
#        11219.4721529 , 15298.56278517,  6288.83215957, 14495.78562658,
#         7497.81367735])

# %%
result["Ridge_prediction"]= ridge_pred
result
# Out:
#       Base_Model  Actual_value         Error  Ridge_prediction
# 0   32093.882621         30760   1333.882621      30363.770710
# 1   20052.042323         13499   6553.042323      18190.790436
# 2    8912.234730          9549   -636.765270       9309.758539
# 3   16717.605450         11850   4867.605450      15766.614753
# 4   20992.446268         28248  -7255.553732      20815.535629
# 5    8005.821155          7799    206.821155       7429.613379
# 6    9046.725190          7788   1258.725190       9060.753339
# 7    5622.670940          9258  -3635.329060       6112.265665
# 8    9585.271773         10198   -612.728227      10035.691996
# 9    7409.875125          7775   -365.124875       7485.559540
# 10  13878.108789         13295    583.108789      13575.017663
# 11   8311.462611          8238     73.462611       8689.509606
# 12  13833.486999         18280  -4446.513001      15417.448057
# 13   9664.529274          9988   -323.470726      10094.892336
# ...

# %%
ridge.score(x_train,y_train)
# Out:
# 0.8457863205015217

# %%
ridge.score(x_test,y_test)
# Out:
# 0.8410544915385927

# %%
from sklearn.metrics import r2_score

# %%
prediction=lr.predict(x_test)

# %%
r2=r2_score(prediction,y_test)

# %%
r2
# Out:
# 0.8008220538917501

# %% [markdown]
# # Conclusions:
# 1. Identify key factors influencing the target variable (e.g., price).
# 2. Assess the quality of the data and its impact on analysis.
# 3. Note any significant trends, patterns, or issues with the data.

# %% [markdown]
# # Recommendations:
#
# 1. Feature Engineering: Enhance or create new features based on key findings.
#
# 2. Data Cleaning: Address missing values or outliers.
#
# 3. Modeling: Suggest appropriate modeling techniques based on feature importance and correlations.
#
# 4. Business Insights: Offer actionable insights for improving pricing or other business strategies.

# %% [markdown]
# # Summary:
# 1.The features 'engine_size' and 'horsepower' show a strong correlation with the automobile price. The price distribution is right-skewed, suggesting some high-priced outliers.
